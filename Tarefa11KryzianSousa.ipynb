# %% [markdown]
# #Kryzian Sousa dos Santos RA: 11202021159

# %% [markdown]
# - **1)** Faça a aproximação de $\pi$ usando a fórmula de Leibniz:
#
# $$\pi \approx 4 - \frac{4}{3} + \frac{4}{5} - \frac{4}{7} + \frac{4}{9}+...$$
#
# Calcule (e mostre na tela) a aproximação de $\pi$ considerando a) 50 termos, b) 500 termos, c) 1000 termos e d) 10000 termos.
#
# Dica: Note que o sinal do termo muda a cada termo. Talvez verificar se o $i$ é par ou ímpar ajude a decidir se para aquele i o sinal é mais ou menos.

# %%
import numpy as np #Comando para importar biblioteca numpy
np.pi #Pi
# Out:
# 3.141592653589793

# %%
np.pi
# Out:
# 3.141592653589793

# %%
n=50 #Definindo variável de acordo com exercício proposto
pi = 0
for i in range(1, n*2+1, 2): #Comando para repetir o código a cada elemento da lista
  sinal = -(-1)**((i+1)/2) #Comandos para alterar o sinal do termo
  pi_i = 4/(i*sinal)
  pi = pi + pi_i
  print(i, sinal, pi_i,pi)
# Out:
# 1 1.0 4.0 4.0
# 3 -1.0 -1.3333333333333333 2.666666666666667
# 5 1.0 0.8 3.466666666666667
# 7 -1.0 -0.5714285714285714 2.8952380952380956
# 9 1.0 0.4444444444444444 3.3396825396825403
# 11 -1.0 -0.36363636363636365 2.9760461760461765
# 13 1.0 0.3076923076923077 3.2837384837384844
# 15 -1.0 -0.26666666666666666 3.017071817071818
# 17 1.0 0.23529411764705882 3.2523659347188767
# 19 -1.0 -0.21052631578947367 3.0418396189294032
# 21 1.0 0.19047619047619047 3.232315809405594
# 23 -1.0 -0.17391304347826086 3.058402765927333
# 25 1.0 0.16 3.2184027659273333
# 27 -1.0 -0.14814814814814814 3.0702546177791854
# 29 1.0 0.13793103448275862 3.208185652261944
# 31 -1.0 -0.12903225806451613 3.079153394197428
# 33 1.0 0.12121212121212122 3.200365515409549
# 35 -1.0 -0.11428571428571428 3.0860798011238346
# 37 1.0 0.10810810810810811 3.1941879092319425
# 39 -1.0 -0.10256410256410256 3.09162380666784
# 41 1.0 0.0975609756097561 3.189184782277596
# 43 -1.0 -0.09302325581395349 3.0961615264636424
# ...

# %%
n=500 #Definindo variável de acordo com exercício proposto
pi = 0
for i in range(1, n*2+1, 2): #Comando para repetir o código a cada elemento da lista
  sinal = -(-1)**((i+1)/2) #Comandos para alterar o sinal do termo
  pi_i = 4/(i*sinal)
  pi = pi + pi_i
  print(i, sinal, pi_i,pi)
# Out:
# 1 1.0 4.0 4.0
# 3 -1.0 -1.3333333333333333 2.666666666666667
# 5 1.0 0.8 3.466666666666667
# 7 -1.0 -0.5714285714285714 2.8952380952380956
# 9 1.0 0.4444444444444444 3.3396825396825403
# 11 -1.0 -0.36363636363636365 2.9760461760461765
# 13 1.0 0.3076923076923077 3.2837384837384844
# 15 -1.0 -0.26666666666666666 3.017071817071818
# 17 1.0 0.23529411764705882 3.2523659347188767
# 19 -1.0 -0.21052631578947367 3.0418396189294032
# 21 1.0 0.19047619047619047 3.232315809405594
# 23 -1.0 -0.17391304347826086 3.058402765927333
# 25 1.0 0.16 3.2184027659273333
# 27 -1.0 -0.14814814814814814 3.0702546177791854
# 29 1.0 0.13793103448275862 3.208185652261944
# 31 -1.0 -0.12903225806451613 3.079153394197428
# 33 1.0 0.12121212121212122 3.200365515409549
# 35 -1.0 -0.11428571428571428 3.0860798011238346
# 37 1.0 0.10810810810810811 3.1941879092319425
# 39 -1.0 -0.10256410256410256 3.09162380666784
# 41 1.0 0.0975609756097561 3.189184782277596
# 43 -1.0 -0.09302325581395349 3.0961615264636424
# ...

# %%
n=1000 #Definindo variável de acordo com exercício proposto
pi = 0
for i in range(1, n*2+1, 2): #Comando para repetir o código a cada elemento da lista
  sinal = -(-1)**((i+1)/2) #Comandos para alterar o sinal do termo
  pi_i = 4/(i*sinal) 
  pi = pi + pi_i
  print(i, sinal, pi_i,pi)
# Out:
# 1 1.0 4.0 4.0
# 3 -1.0 -1.3333333333333333 2.666666666666667
# 5 1.0 0.8 3.466666666666667
# 7 -1.0 -0.5714285714285714 2.8952380952380956
# 9 1.0 0.4444444444444444 3.3396825396825403
# 11 -1.0 -0.36363636363636365 2.9760461760461765
# 13 1.0 0.3076923076923077 3.2837384837384844
# 15 -1.0 -0.26666666666666666 3.017071817071818
# 17 1.0 0.23529411764705882 3.2523659347188767
# 19 -1.0 -0.21052631578947367 3.0418396189294032
# 21 1.0 0.19047619047619047 3.232315809405594
# 23 -1.0 -0.17391304347826086 3.058402765927333
# 25 1.0 0.16 3.2184027659273333
# 27 -1.0 -0.14814814814814814 3.0702546177791854
# 29 1.0 0.13793103448275862 3.208185652261944
# 31 -1.0 -0.12903225806451613 3.079153394197428
# 33 1.0 0.12121212121212122 3.200365515409549
# 35 -1.0 -0.11428571428571428 3.0860798011238346
# 37 1.0 0.10810810810810811 3.1941879092319425
# 39 -1.0 -0.10256410256410256 3.09162380666784
# 41 1.0 0.0975609756097561 3.189184782277596
# 43 -1.0 -0.09302325581395349 3.0961615264636424
# ...

# %%
n=10000 #Definindo variável de acordo com exercício proposto
pi = 0
for i in range(1, n*2+1, 2): #Comando para repetir o código a cada elemento da lista
  sinal = -(-1)**((i+1)/2) #Comandos para alterar o sinal do termo
  pi_i = 4/(i*sinal)
  pi = pi + pi_i
  print(i, sinal, pi_i,pi)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 10001 1.0 0.00039996000399960006 3.1417926135957908
# 10003 -1.0 -0.00039988003598920324 3.1413927335598015
# 10005 1.0 0.000399800099950025 3.1417925336597516
# 10007 -1.0 -0.000399720195862896 3.141392813463889
# 10009 1.0 0.0003996403237086622 3.1417924537875974
# 10011 -1.0 -0.000399560483468185 3.141392893304129
# 10013 1.0 0.00039948067512234097 3.1417923739792513
# 10015 -1.0 -0.00039940089865202194 3.1413929730805994
# 10017 1.0 0.0003993211540381352 3.1417922942346377
# 10019 -1.0 -0.00039924144126160294 3.141393052793376
# 10021 1.0 0.00039916176030336295 3.1417922145536794
# 10023 -1.0 -0.00039908211114436795 3.141393132442535
# 10025 1.0 0.00039900249376558606 3.1417921349363005
# 10027 -1.0 -0.0003989229081480004 3.1413932120281527
# 10029 1.0 0.0003988433542726094 3.1417920553824255
# 10031 -1.0 -0.00039876383212042666 3.141393291550305
# 10033 1.0 0.0003986843416724808 3.1417919758919775
# ...
